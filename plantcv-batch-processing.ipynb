# %% [markdown]
# # Create a configuration file for batch processing

# %%
import plantcv.parallel

# %%
config = plantcv.parallel.WorkflowConfig()

# %%
config.save_config(config_file="sorghum_morphology_workflow_config.json")
